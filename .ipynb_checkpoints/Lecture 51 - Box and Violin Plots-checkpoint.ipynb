# %%
# The normal inports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules odn libraries we'll use
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %% [markdown]
# url = 'https://ru.wikipedia.org/wiki/Файл:Boxplot_vs_PDF.png'

# %%
data1 = randn(100)
data2 = randn(100)

# %%
sns.boxplot([data1,data2])

# %%
sns.boxplot([data1, data2],whis=np.inf)

# %%
sns.boxplot(data1)

# %%
# Normal Dist
data1 = stats.norm(0,5).rvs(100)

# Two gama dist. Concatenated togeter\
data2 = np.concatenate([stats.gamma(5).rvs(50)-1, 
                        -1*stats.gamma(5).rvs(50)])

#Box plot both data1 and data2
sns.boxplot([data1,data2], whis=np.inf)

# %%
sns.violinplot([data1, data2])

# %%
sns.violinplot(data2, bw=0.1)

# %%
sns.violinplot(data2, inner='stick')
