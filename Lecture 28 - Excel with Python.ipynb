# %%
import pandas as pd

# %%
excel_file = 'Otchet.xls'

# %%
excel_data = pd.read_excel(excel_file, header = 4)
excel_data
# Out:
#                                 Дата звонка Время звонка Инициатор звонка  \
# 0                                10.01.2020     10:46:51       9059545451
# 1                                10.01.2020     08:08:03       9059545451
# 2                                09.01.2020     21:24:02    85.115.241.14
# 3                                09.01.2020     21:23:13    85.115.241.14
# 4                                09.01.2020     21:14:40    85.115.241.14
# ...                                     ...          ...              ...
# 2607                                    NaN          NaN              NaN
# 2608                                    NaN          NaN              NaN
# 2609                                 Итого:          NaN              NaN
# 2610  Итоговая стоимость по звонкам (руб.):       731.49              NaN
# 2611            Итоговый объем данных (MB):      6630.65              NaN
#
#      Набранный номер                Тип звонка                  Услуга  \
# ...
